# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler,OneHotEncoder,LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, chi2
import numpy as np

# %%
df = pd.read_csv('bhutan_fuel_prices.csv')

# %%
df
# Out:
#                Region      Product                               Company  \
# 0      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 1      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 2      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 3      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 4      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# ...               ...          ...                                   ...
# 11373  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11374  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11375  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11376  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11377                         NaN                                   NaN
#
#       Approved_Date        Station     RSP/KL   RSP/L
# ...

# %%
df = df.drop('Approved_Date', axis = 1)

# %%
df
# Out:
#                Region      Product                               Company  \
# 0      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 1      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 2      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 3      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 4      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# ...               ...          ...                                   ...
# 11373  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11374  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11375  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11376  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11377                         NaN                                   NaN
#
#              Station     RSP/KL   RSP/L
# 0      Phuentsholing   98497.76   98.50
# ...

# %%
df = df.drop('RSP/KL', axis=1)

# %%
df
# Out:
#                Region      Product                               Company  \
# 0      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 1      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 2      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 3      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 4      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# ...               ...          ...                                   ...
# 11373  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11374  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11375  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11376  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11377                         NaN                                   NaN
#
#              Station   RSP/L
# 0      Phuentsholing   98.50
# 1        Rinchending   98.58
# ...

# %%
df.isna().sum()
# Out:
# Region      0
# Product     1
# Company    16
# Station    30
# RSP/L       1
# dtype: int64

# %%
df.dtypes
# Out:
# Region      object
# Product     object
# Company     object
# Station     object
# RSP/L      float64
# dtype: object

# %%
df['price'] = df['RSP/L']

# %%
df
# Out:
#                Region      Product                               Company  \
# 0      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 1      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 2      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 3      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 4      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# ...               ...          ...                                   ...
# 11373  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11374  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11375  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11376  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11377                         NaN                                   NaN
#
#              Station   RSP/L   price
# 0      Phuentsholing   98.50   98.50
# ...

# %%
df = df.drop('RSP/L', axis = 1)

# %%
df
# Out:
#                Region      Product                               Company  \
# 0      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 1      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 2      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 3      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 4      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# ...               ...          ...                                   ...
# 11373  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11374  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11375  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11376  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11377                         NaN                                   NaN
#
#              Station   price
# 0      Phuentsholing   98.50
# 1        Rinchending   98.58
# ...

# %%
 df.dropna(subset=['price'],inplace=True)

# %%
df.isna().sum()
# Out:
# Region      0
# Product     0
# Company    15
# Station    29
# price       0
# dtype: int64

# %%
x = df.drop('price',axis =1)

# %%
x
# Out:
#                Region      Product                               Company  \
# 0      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 1      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 2      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 3      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# 4      Western Region  HSD (in KL)  Bharat Petroleum Corporation Limited
# ...               ...          ...                                   ...
# 11372  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11373  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11374  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11375  Central Region   MS (in KL)        Indian Oil Corporation Limited
# 11376  Central Region   MS (in KL)        Indian Oil Corporation Limited
#
#              Station
# 0      Phuentsholing
# 1        Rinchending
# 2            Pasakha
# ...

# %%
y = df['price']

# %%
y
# Out:
# 0         98.50
# 1         98.58
# 2         98.63
# 3        100.21
# 4        100.65
#           ...
# 11372     42.16
# 11373     41.07
# 11374     43.47
# 11375     41.61
# 11376     41.22
# Name: price, Length: 11377, dtype: float64

# %%
xtrain,ytrain,xtest,ytest = train_test_split(x,y, test_size=0.2,random_state=5,shuffle=True)

# %%
# n_transformer = Pipeline(steps = [
#     ('impute_n ', SimpleImputer(fill_value='missing',strategy='mean')),
  
# ])

# %%
pl = Pipeline([
    #('impute',SimpleImputer(missing_values=np.nan, strategy='mean')),
     ('imput',SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
    
    
    ('one', OneHotEncoder(sparse =False,handle_unknown='ignore')),
    ('scaler' , StandardScaler()),
   
    ('ir_classifier', DecisionTreeClassifier())
])

# %%
pl2 = Pipeline([
    
    ('imput',SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
    
    ('one', OneHotEncoder(sparse = False,handle_unknown='ignore')),
    ('scaler2', StandardScaler()),
   
    ('ir_classifier2',LogisticRegression(random_state=0))
])

# %%
pipelines = [pl,pl2]
pipedict = {0:'DicisionTree',1:'LogisticRegression'}

# %%
for pipe in pipelines:
    pipe.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GYELTS~2\AppData\Local\Temp/ipykernel_5776/3573020777.py in <module>
#       1 for pipe in pipelines:
# ----> 2     pipe.fit(xtrain,ytrain)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ...

# %%
for i,model in enumerate(pipelines):
    print('{} Test Accuracy: {}'.format(pipedict[i],model.score(xtest,ytest)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GYELTS~2\AppData\Local\Temp/ipykernel_12768/2108547615.py in <module>
#       1 for i,model in enumerate(pipelines):
# ----> 2     print('{} Test Accuracy: {}'.format(pipedict[i],model.score(xtest,ytest)))
#       3
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in score(self, X, y, sample_weight)
#     616         Xt = X
#     617         for _, name, transform in self._iter(with_final=False):
# ...

# %%
processer = ColumnTransformer(
    transformers=[
    ('c_trans', c_transformer, [0,1,2,3])]
    
    
)

# %%
dmtl = DecisionTreeRegressor()

# %%
test_model = Pipeline( steps =[
    ('pre',processer),
    ('model', dmtl)
])

# %%
xtrain = xtrain.values
ytrain = ytrain.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\GYELTS~2\AppData\Local\Temp/ipykernel_12768/2237369648.py in <module>
# ----> 1 xtrain = xtrain.values
#       2 ytrain = ytrain.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
test_model.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GYELTS~2\AppData\Local\Temp/ipykernel_12768/3373294213.py in <module>
# ----> 1 test_model.fit(xtrain,ytrain)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1250         """
#    1251
# -> 1252         super().fit(
#    1253             X, y,
#    1254             sample_weight=sample_weight,
#
# ...
